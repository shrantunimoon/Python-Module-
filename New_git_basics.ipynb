# %%
#python is a programing language
#1)it is easy and english like
#2)open source : it is free to use
#3)it has a huge community  : it useful for debugging,have many libraries
#4)intepreted :line by line execution
#5)dynamic:automates a lot of processing by itself
#6)multipurpose:frontend ,backend,game developement,datascience etc
#7)platform independent:can run on various platforms by simple installation
#8)embeddable:embedding python code in between other programing language code
#9)extensible: putting some other language code with the python code

# %% [markdown]
# # Python
# ## python
# ### python

# %% [markdown]
# python

# %% [markdown]
# # python

# %%
this is a python class
# Out:
#   Cell In[10], line 1
#     this is a python class
#               ^
# SyntaxError: invalid syntax

# %%
#python

# %%
a=100
b=kat
c=1200
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a=100
# ----> 2 b=kat
#       3 c=1200
#
# NameError: name 'kat' is not defined

# %%
a
# Out:
# 100

# %%
a=100
a='sharma'
a=12.78
a=9+8j 
a
# Out:
# (9+8j)

# %%
#IDE: Integrated development environment
1)IDLE
2)jupyter notebook: does not require internet,intranet
3)collab:requires internet
4)visual studio
5)pycharm
6)spyder

# %%
#this is a cell
'''this is multiple line ,
statement ,in he
jupyter notebook'''
a=100
a
# Out:
# 100

# %%
#variables
a=100 
#1a=100
a1=100

# %%
1)a=100 
2)A='SUBMISSIONS'
3)a1=23
4)Yourname=True,
5)yournamesurname='er',
6)your name='er',
7)supernumber123=11,
8)1_christmas=78, 
9)_christmas=1212,
10)___christmas=12134,
11)1@christmas=12,
12)@y=11,
13)y@x=90,              
14)amount=100,
15)AMOUNT=400,
16)Amount=220,
17)AmOuNt=900,
18)CountWord=230,
19)Count_Word=450,
20)$currency=120,
21)currency%=100

# %%
#variables starts with letters  and underscore 
#no spaces between the words
#special  characters are not allowed except underscore 
anywhere in the whole variable
#numbers are not allowed in the begging of the variable
#python is case senstive
#length of the variable is not an issue

# %%
a1=10
a1w=10

# %%
#roll no=10
roll_no=10 #snake casing
RollNo=10 #camel casing

# %%
A=10
a=90
a
A
# Out:
# 10

# %%
aaaaaackhsodhvcsocsdhudw=100

# %%
a=19999999999999999999999999999999999999999999

# %%
#datatype :types of data
a=100 #int
b="kavita" #strings 
c=18.9 #float
d=True #boolean
e=10+8j#complex 
print(a,b)
# Out:
# 100 kavita

# %%
#print(a,b) 
print('this is the value of  a and b',a,b)
# Out:
# this is a a and b 100 kavita

# %%
a='a'

# %%
ord('a') #'ord'to get the asci value
ord('A')
# Out:
# 65

# %%
a=100

# %%
print

# %%
alpha

# %%
#keywords:are pre-defined words whose meaning is know to the system

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if =10 #keywprds cannot be used as variable
# Out:
#   Cell In[48], line 1
#     if =10
#        ^
# SyntaxError: invalid syntax

# %%
print=10 
''' this will work but it will over write the functionalities for print
and now print function will not work the same...
to bring back the old functionality of print ...first refresh the kernel 
now try using print the usual way '''

# %% [markdown]
# ## Arithematic operator:+,-,*,**,/,//,%

# %%
a=10
b=2 
print('the value of a is {} and b is {} and a+b is {}'.format(a,b,a+b))
# Out:
# the value of a is 10 and b is 2 and a+b is 12

# %%
#print('this is the value of a,b',a,b) 
#print('the value of a is {} and b is {}'.format(a,b)) 
#print('the value of a is {b} and b is {a}'.format(a=100,b=200)) 
print('the value of a is {1} and b is {0}'.format(a,b))
# Out:
# the value of a is 2 and b is 10

# %%
+,-,*,**,/,

# %% [markdown]
# # logical operator:and ,or,not

# %%
a=True
b=False
a and b
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
a=12 #a has some value, thereby considered as 1
b='' #has an empty string ,thereby considered as 0
c=90
a or b 
'''has to give output 1,so it throws answers as 12
regarless of the order in which they are passed'''
b or a
#c or b or a
# Out:
# 12

# %%
a="this is meenal's bag"
a='meenal said "this is my bag".'
a=90

# %% [markdown]
# # relational operator: >,<,>=,<=,==,!=

# %%
a=10
b=8
print('the value of a {} and b {} and a>b is {}'.format(a,b,a>b))
# Out:
# the value of a 10 and b 8 and a>b is True

# %%
a=10
b=10
a!=b
# Out:
# False

# %%
a=10
b=20
(a>30)and (b>10)

# %% [markdown]
# # Bitwise operator

# %%
&,|,^,~,<<,>>

# %%
bin(15)
# Out:
# '0b1111'

# %%
bin(14)
# Out:
# '0b1110'

# %%
bin(22)
# Out:
# '0b10110'

# %%
7&10
# Out:
# 2

# %%
12&8
# Out:
# 8

# %%
12|8
# Out:
# 12

# %%
~10
# Out:
# -11

# %%
~12 #-(n+1)---->to perform negation using bitwise operator
# Out:
# -13

# %%
12>>3
# Out:
# 1

# %%
12<<3
# Out:
# 96

# %%
10^7 #dissimilar bits will give me 1 as an answer
# Out:
# 13

# %%
#assignment operator

# %%
a=10
#a-=2
a &=9
a
# Out:
# 8

# %%
a=10
#print(a &=9) 
#print('the value of a {a} after updation is {a}'.format(a=10,a&=9)) 
print(a>=2) 
a
# Out:
# True
# 10

# %%
a=10
a&9
# Out:
# 8

# %%
10>=2
# Out:
# True

# %%
a=10
b=9
#a+b
#a+8
#a=a+8
#c=a+b 
#a=a+b
a+=b
# Out:
# 9

# %%
a=10
a&=9
a
# Out:
# 8

# %% [markdown]
# # Identity operator

# %%
is ,is not

# %%
a=10
print(id(a))
b=10
print(id(b))
a is b
# Out:
# 140707599035096
# 140707599035096
# True

# %%
a='manisha is ' 
print(id(a))
b='manisha is'
print(id(b))
a is b
# Out:
# 1925588127152
# 1925588128304
# False

# %%
a=1000
print(id(a))
b=1000
print(id(b))
a is b
# Out:
# 1925586807408
# 1925586808464
# False

# %%
a=1000000
b=1000000
a==b
a is b
# Out:
# True

# %%
a=10
b=10
a is not b
# Out:
# False

# %%
a=-5
b=-5
a is b
# Out:
# True

# %%
a=256
b=256
a is b
# Out:
# False

# %%
10,10,20,20,30

# %%
a=10
b+=20
c=a+b
c
# Out:
# 307

# %%
3,3,4,5,4

# %%
#Membership operator:in ,not in
a='manish'
'a' in a
#iterable
a in 'a'
# Out:
# False
