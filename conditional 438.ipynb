# %%
1) fix the word in my mind
2) ask the word 
3)collect answer
4)checking/matching the answer with my answer
5)Announce "word matched" or "not matched"

# %%
my_word="Tubelight" 
student=eval(input('give your word')) 
my_word==student 
print('word matched')
# Out:
# give your word 'Tubelight'
# word matched

# %%
my_word="Tubelight" 
student=eval(input('give your word')) 
my_word==student 
#print('word matched')
# Out:
# give your word ['fan','chair','hand']
# False

# %%
my_word="Tubelight" 
student=eval(input('give your word')) 
myord_word==student
print('w matched')
# Out:
# give your word ["Tubelight"]
# word matched

# %%
#conditional statement:if
my_word="Tubelight" 
student=eval(input('give your word')) 
if my_word==student :  #spacing is called indentation
     print('word matched')
     print('this is a line in if')
     print('new line in if') 
print('thank you')


#consistent spacing is important 
#while creating the body of a conditional statement
# Out:
# give your word "Tubelight"
# word matched
# this is a line in if
# new line in if
# thank you

# %%
a=10
if a:
    print('this is in if')
print('new stat')
# Out:
# this is in if
# new stat

# %%
a=''
if a:
    print('this is in if')
print('new stat')
# Out:
# new stat

# %%
a=' '
if a:
    print('this is in if')

print('new stat')
# Out:
# this is in if
# new stat

# %%
a=[]
if a:
    print('this is in if')
print('new stat')
# Out:
# new stat

# %%
#check if someone is eligible to vote

# %%
a=2
if a>=18:
    print('eligible') 
print('thank you')
# Out:
# thank you

# %%
a=int(input('give your age'))
if a>=18:
    print('eligible')  
if a<18:
    print('not eligible') 
print('thank you')
# Out:
# give your age 18
# eligible
# thank you

# %%
a=int(input('give your age') )

if a>=18:
    print('eligible')  
if a<18:
    print('not eligible')  

print('thank you')
# Out:
# give your age kl
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 a=input('give your age')
#       2 #a=int(a)
# ----> 3 if a>=18:
#       4     print('eligible')
#       5 if a<18:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
vowels-a e i o u

# %%
word='ae'
vowels=['a','e','i','o','u']
if word[0] in vowels or word[1] in vowels: 
    print('vowels present')
# Out:
# vowels present

# %%
word='shankar'
if 'a' in word or 'e' in word:
    print('vowel present')
# Out:
# vowel present

# %%
a='90'
b=['67',90] 
#b in a #cannot iterate over a 
#b in a #cannot search list in a string
#a in b #a is the thing you are searching and b is the place 
a in b
# Out:
# False

# %%
#if else 
a=90
if a==90 :
    print('yes') 
else:  #cannot exist without if, does not have any condition to validate
    print('no')

# %%
1)ask the user name and age
2) check if the age is greater than or equal to 21
if yes,then print 'welcome to club' else 'not welcome;

# %%
name= input('give your name')  
age=int(input('give your age')) 
if age>=21:
    print('welcome')
else :
    print('next time')

# %%
info=eval(input('give name and age'))
# Out:
# give name and age ['manisha',34]

# %%
#even odd

# %%
a=eval(input('no.')) 
if type(a)==int:
    #print('yes')
    if a %2==0:
        print(a,'even')
    else:
        print(a,'odd') 
else:
    print('give proper input')
# Out:
# no. [90]
# give proper input

# %%
#check if the age is more than 21 and if so then check if their name starts with 'Y'
if yes then print "you won lottery",else "did not win"

# %%
age=int(input('give your age'))
name=input('give your name') 
if age>=21:
    if name[0]=='y' or name[0]=='Y':
        print('won lottery') 
    else:
        print('no lottery') 
else:
    print('age less than 21')

# %%
info=eval(input('give your name and  age'))
if info[1]>=21:
    if info[0][0]=='y' or info[0][0]=='Y':
        print('won lottery') 
    else:
        print('no lottery') 
else:
    print('age less than 21')

# %%
age=int(input('give your age'))
name=input('give your name') 
if age>=21:
    if name[0].startswith('y') or name[0].startswith('Y'):
        print('won lottery') 
    else:
        print('no lottery') 
else:
    print('age less than 21')
# Out:
# give your age 22
# give your name kavita
# no lottery

# %%
marks=90
if marks<45:
    print('fail')
else:
    print('pass')

# %%
#if someone is age 21 -45 ---then enter club 1
if their age is 45--70---club 2
if more than 70---no club

# %%
#elif :to check multiple conditions,cannot exist with if
age=-22
name='mahima'
if name=='mahima':
    print('club 0')
elif age>=21 and age<45:
    print('club1')
elif age >=45 and age<70:
    print('club2')
elif age>=70:
    print('no club') 
else:
    print('nothing')
print('outside cond.')
# Out:
# club 0
# outside cond.

# %%
30-50: D
50-70:c

70-80:b
80-90:a
90-100:a1

# %%
fizz buzz ,prime composite,triangle type ,password strength

# %% [raw]
# for i in range(65,91):
#     print(chr(i),end='')
#     print()
#     print(chr(i+32))

# %%
ord('Z')
# Out:
# 90

# %%
ord('a')
# Out:
# 97

# %%
#divisible by 3 --->fizz
divisible by 5 --->buzz
divisible by 3 &5--->fizzbuzz

# %%
num=6

# %%
#all conditions should be checked
if cond1

if cond2

if cond3

# %%
if cond1:
    if con1:

    elif

    else:

else:

# %%
#only one condition shoud be true
if cond1

elif cond2

elif cond3

else

# %%
#health checkups : if all three checkups are fine--> then health is fine else not fine

# %%
a=30
if a %5==0 and a%3==0:
    print('fizz buzz')
elif a%5==0:
    print('buzz')
elif a%3==0:
    print('fizz ')
# Out:
# fizz buzz

# %%
heartbeat=122
bp=121
diab=90
Heart_report='unfine'
Bp_report='unfine'
Diab_report='unfine'

if heartbeat>=80 and heartbeat<=120:
    Heart_report='fine'
    #print(Heart_report)
if bp>=120 and bp<=140:
    Bp_report='fine'
    #print(Bp_report)
if diab>=60 and diab<=140:
    Diab_report='fine'
    #print(Diab_report)
if Heart_report=='fine' and Bp_report=='fine' and Diab_report=='fine':
    print('you are healthy')
else:
    print('not healthy')
# Out:
# not healthy

# %%
if heartbet < --->
   if diab<---->
       if bp<--->
            print('healthy') 
       else: 
            print('bp unwel)
   else: 
      print(diab issue)
        
    
else:
    print('heartt unwel')

# %%
a=4
if a%2==0 or a%3==0:
    print('composite') 
else:
    print(prime)

# %%
a=3
if a%2==0 :
    print('composite') 
else:
    print(prime)

# %%
1)all no. 1 to num. itself
2)all no. will always have two factors one and itself

# %%
a=12
if a%2 ==0 or a%3==0

# %% [raw]
# #walrus operator  : It assigns a value to a variable and returns that value in the same expression.

# %%
if (n := len([1,2,3,4,5])) > 3:
    print(f"List is long with {n} items")

# %%
(a:=3+3 if a>7 else'makhi') 
a
